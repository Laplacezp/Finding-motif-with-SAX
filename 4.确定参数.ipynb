# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
sys.path.insert(0, "../")

import motiflets as ml
from motiflets import competitors
from motiflets import plotting
from motiflets import motiflets


import subprocess
import matplotlib
import pandas as pd
import numpy as np
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}

import warnings
warnings.simplefilter("ignore")

# %%
ds_name = "ECG Heartbeat"
file = 'ecg-heartbeat-av.csv'
series, df_gt = motiflets.read_dataset_with_index(file)
plotting.plot_dataset(ds_name, series, ground_truth=df_gt)
# Out:
# Dataset Original Length n:  3000
# Dataset Sampled Length n:  3000
# ../datasets/ground_truth/ecg-heartbeat-av_gt.csv
# (<Figure size 1440x216 with 1 Axes>,
#  [<AxesSubplot:title={'center':'ECG Heartbeat'}, xlabel='Seconds'>])

# %%
df = pd.DataFrame() # TOP-1 motifs
df2 = pd.DataFrame() # TOP-2 motifs
rerun_all_jars = False
ks=20
dataset = os.getcwd() + '/../datasets/' + file

# %%
length_range = np.arange(25,200,25) 
motif_length = plot_motif_length_selection(
    ks,
    series,
    motif_length_range=length_range,
    ds_name=ds_name)

print ("Best motif length", series.index[motif_length], "seconds")
# Out:
# Compute ks (20):   0%|          | 0/18 [00:00<?, ?it/s]
# Compute ks (20):   0%|          | 0/18 [00:00<?, ?it/s]
# Compute ks (20):   0%|          | 0/18 [00:00<?, ?it/s]
# Compute ks (20):   0%|          | 0/18 [00:00<?, ?it/s]
# Compute ks (20):   0%|          | 0/18 [00:00<?, ?it/s]
# Compute ks (20):   0%|          | 0/18 [00:00<?, ?it/s]
# Compute ks (20):   0%|          | 0/18 [00:00<?, ?it/s]
# 	Time 3.9 s
# Best motif length 0.9765625 seconds
